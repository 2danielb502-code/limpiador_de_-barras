# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Cargar MNIST
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalizar
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Aplanar
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# Modelo denso profundo
model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(128, activation='relu'),
    
    layers.Dense(10, activation='softmax')
])

# Compilar
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Entrenar
model.fit(x_train, y_train, epochs=10, batch_size=128)

# Evaluar
loss, acc = model.evaluate(x_test, y_test)
print("Precisión:", acc)
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9096 - loss: 0.2954
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9612 - loss: 0.1283
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9703 - loss: 0.0931
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9751 - loss: 0.0788
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9789 - loss: 0.0666
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9814 - loss: 0.0578
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9825 - loss: 0.0544
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9850 - loss: 0.0467
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9855 - loss: 0.0455
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9871 - loss: 0.0408
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9838 - loss: 0.0617
# Precisión: 0.9837999939918518

# %%
from tensorflow.keras.models import load_model

# Cargar modelo
model = load_model("modelo_ropa.keras")

print("Modelo cargado correctamente")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 from tensorflow.keras.models import load_model
#       3 # Cargar modelo
# ----> 4 model = load_model("modelo_ropa.keras")
#       6 print("Modelo cargado correctamente")
#
# File c:\Users\dbecerraq\.conda\envs\mnist_tf\lib\site-packages\keras\src\saving\saving_api.py:203, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
# --> 203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#     208 else:
#     209     raise ValueError(
#     210         f"File format not supported: filepath={filepath}. "
#     211         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     220         "might have a different name)."
#     221     )
#
# ValueError: File not found: filepath=modelo_ropa.keras. Please ensure the file is an accessible `.keras` zip file.
